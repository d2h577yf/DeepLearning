# %%
# %matplotlib inline
import torch
from torch.distributions import multinomial
import numpy as np

# %%
fair_probs = torch.ones(6) / 6
sample = multinomial.Multinomial(19999, fair_probs).sample()
print(sample / 19999)
# Out:
# tensor([0.1684, 0.1651, 0.1647, 0.1678, 0.1692, 0.1649])
